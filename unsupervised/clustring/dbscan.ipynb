# %%
from sklearn.datasets import load_iris
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
iris=load_iris()
X=iris.data
y=iris.target

# %%
scaler =StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
#visualize
sns.scatterplot(x=X_scaled[:,0],y=X_scaled[:,2])
# Out:
# <Axes: >

# %%
#DBSCAN
from sklearn.cluster import DBSCAN

clustring=DBSCAN(
    eps=0.8,
    min_samples=5
).fit_predict(X_scaled)

# %%
sns.scatterplot(x=X_scaled[:,0],y=X_scaled[:,2],c=clustring)
# Out:
# <Axes: >

# %%
###NON _ LInear DAtA
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
import seaborn as sns
import matplotlib.pyplot as plt
X, y = make_moons(n_samples=200, noise=0.05, random_state=42)

# %%
X_scaled=scaler.fit_transform(X)
sns.scatterplot(x=X[:,0], y=X[:,1], hue=labels)
# Out:
# <Axes: >

# %%
#K-means
from sklearn.cluster import KMeans

kmeans=KMeans(
    n_clusters=2,
    random_state=42
)

labels=kmeans.fit_predict(X_scaled)
sns.scatterplot(x=X[:,0], y=X[:,1], hue=labels)
# Out:
# C:\Users\Rahul shakya\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# <Axes: >

# %%
#DBSCAN
dbscan=DBSCAN(
    eps=0.5,
    min_samples=5
)

labels=dbscan.fit_predict(X_scaled)
sns.scatterplot(x=X[:,0], y=X[:,1], hue=labels)
# Out:
# <Axes: >
