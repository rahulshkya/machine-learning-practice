# %%
import numpy as np

# %%
arr=np.array([[1,2,3],[1,2,3],[1,2,3]])
print(arr)
# Out:
# [[1 2 3]
#  [1 2 3]
#  [1 2 3]]

# %%
#create
arr1=np.zeros((2,3)) #prefill
print(arr1,arr1.shape)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]] (2, 3)

# %%
arr5=np.linspace(1,100,4)
print(arr5)
# Out:
# [  1.  34.  67. 100.]

# %%
arr=np.array([[1,2,3,4,5,6],[1,2,3,4,5,4]])
print(arr.shape)
print(arr.dtype)
# Out:
# (2, 6)
# int64

# %%
#operation on arrays
arr=np.array([[1,2,3],[4,5,6]])
print(arr,arr.shape)

reshaped = arr.reshape((3,2))
print(reshaped)

idx=[0]
flat=arr.flatten()
print(flat)

print(arr[idx])
# Out:
# [[1 2 3]
#  [4 5 6]] (2, 3)
# [[1 2]
#  [3 4]
#  [5 6]]
# [1 2 3 4 5 6]
# [[1 2 3]]

# %%
arr=np.array([1,2,3,4,5])
arr2=arr**2

print(arr2)
# Out:
# [ 1  4  9 16 25]

# %%
 #brodcasting
print(arr*5)
# Out:
# [ 5 10 15 20 25]

# %%
#normalize

arrs=np.array([[1,2],[3,4]])

mean=np.mean(arrs)
std=np.std(arrs)

norms=(arrs-mean)/std
print(norms)
# Out:
# [[-1.34164079 -0.4472136 ]
#  [ 0.4472136   1.34164079]]

# %%
print(np.trunc(3.55))
# Out:
# 3.0
