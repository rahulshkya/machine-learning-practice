# %%
import pandas as pd

# %%
info={
    "name":["rahul","harshita","shardha"],
    "CGPA":[9.5,5.4,8.5]
}
df=pd.DataFrame(info)
print(df)
# Out:
#        name  CGPA
# 0     rahul   9.5
# 1  harshita   5.4
# 2   shardha   8.5

# %%
df
# Out:
#        name  CGPA
# 0     rahul   9.5
# 1  harshita   5.4
# 2   shardha   8.5

# %%
s=pd.Series([18,20,30,40,50],index=["adam","eve","bob","charlie","rahul"])
print(s)
print(s["adam"])
# Out:
# adam       18
# eve        20
# bob        30
# charlie    40
# rahul      50
# dtype: int64
# 18

# %%
s
# Out:
# adam       18
# eve        20
# bob        30
# charlie    40
# rahul      50
# dtype: int64

# %%
 s1=pd.Series([1,2,3,4])
s2=pd.Series([1,2,3,4])

print(s1+s2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2],
   "rate":[20000,100000,3000000]
}

myvar = pd.DataFrame(mydataset, index=["rahul", "charlie", "prag"])
print(myvar)
# Out:
#           cars  passings     rate
# rahul      BMW         3    20000
# charlie  Volvo         7   100000
# prag      Ford         2  3000000

# %%
df=pd.read_csv("employee_data.csv")

# %%
print(df.describe())
# Out:
#              ID        Age        Salary
# count  10.00000  10.000000     10.000000
# mean    5.50000  32.900000  64500.000000
# std     3.02765   6.674162  15182.226451
# min     1.00000  25.000000  47000.000000
# 25%     3.25000  28.250000  51250.000000
# 50%     5.50000  31.000000  62500.000000
# 75%     7.75000  37.250000  74250.000000
# max    10.00000  45.000000  91000.000000

# %%
#AQI data set
aqis=pd.read_csv("globalAirQuality.csv")
print(aqi)
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
aqi
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
aqi.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 aqi.head()
#
# NameError: name 'aqi' is not defined

# %%
#selecting data
aqis[["city","aqi"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #selecting data
# ----> 2 aqis[["city","aqi"]]
#
# NameError: name 'aqis' is not defined

# %%
aqis["pm25"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 aqis["pm25"]
#
# NameError: name 'aqis' is not defined
