# %%
import numpy as np
import time

# %%
size=10_000_000
py_list=list(range(size))

start=time.time()
sqlist=[x**2 for x in py_list]
end=time.time()

print(f"python list time ={end-start} seconds")

np_arr=np.array(py_list)

start=time.time()
np_sq=np_arr**2
end=time.time()

print(f"numpy array time = {end-start} seconds")
# Out:
# python list time =1.5447101593017578 seconds
# numpy array time = 0.030274152755737305 seconds

# %%
import sys

print(f"python list size ={sys.getsizeof(py_list)*len(py_list)} bytes")

print(f"numpy array size = {np_arr.nbytes} bytes")
# Out:
# python list size =800000560000000 bytes
# numpy array size = 80000000 bytes
