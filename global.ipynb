# %%
import pandas as pd

# %%
AQI=pd.read_csv("globalAirQuality.csv")

# %%
AQI
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
AQI.at[0,"city"]
# Out:
# 'New York'

# %%
#filtering data
aqi_data=100
AQI.query("aqi > @aqi_data & temperature > 37.914")[["city","temperature"]]
# Out:
#                    city  temperature
# 1095              Paris       37.980
# 1124              Paris       37.922
# 2079             Madrid       37.929
# 4558              Cairo       37.990
# 4910            Nairobi       37.930
# 4960            Nairobi       37.974
# 5432              Dubai       37.959
# 5695              Dubai       37.965
# 6490             Mumbai       37.937
# 7066              Delhi       37.932
# 7587            Kolkata       37.958
# 8079            Chennai       37.939
# 8659              Osaka       37.952
# 9627            Beijing       37.995
# 10070          Shanghai       37.986
# 10161         Hong Kong       37.942
# 10163         Hong Kong       37.918
# 11338      Kuala Lumpur       37.927
# 11576           Jakarta       37.966
# 11866           Jakarta       37.973
# 12549         Melbourne       37.960
# 14893  Ho Chi Minh City       37.921
# 15042  Ho Chi Minh City       37.998
# 15269     San Francisco       37.938
# ...
