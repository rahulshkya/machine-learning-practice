# %%
# !pip install torchvision
# !pip install pillow
# Out:
# Requirement already satisfied: torchvision in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (0.20.1)
# Requirement already satisfied: numpy in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from torchvision) (2.0.1)
# Requirement already satisfied: torch==2.5.1 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from torchvision) (2.5.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: filelock in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from torch==2.5.1->torchvision) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from torch==2.5.1->torchvision) (4.15.0)
# Requirement already satisfied: sympy==1.13.1 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from torch==2.5.1->torchvision) (1.13.1)
# Requirement already satisfied: networkx in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from torch==2.5.1->torchvision) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from torch==2.5.1->torchvision) (3.1.6)
# Requirement already satisfied: fsspec in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from torch==2.5.1->torchvision) (2026.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from sympy==1.13.1->torch==2.5.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from jinja2->torch==2.5.1->torchvision) (3.0.2)
# Requirement already satisfied: pillow in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (11.1.0)

# %%
import torch
import os
from torch.utils.data import DataLoader,Dataset
from torchvision import transforms
from PIL import Image

# %%
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import os

transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5),
                         (0.5, 0.5, 0.5))
])

class ImageProcessor(Dataset):
    def __init__(self, root_dir_path, transformation=None):
        self.root_dir_path = root_dir_path
        self.transformation = transformation
        self.all_img_paths = [
            os.path.join(root_dir_path, img)
            for img in os.listdir(root_dir_path)
            if img.lower().endswith(('.jpg', '.jpeg', '.png'))
        ]

    def __len__(self):
        return len(self.all_img_paths)

    def __getitem__(self, idx):
        img_path = self.all_img_paths[idx]
        img = Image.open(img_path).convert("RGB")

        if self.transformation:
            img = self.transformation(img)

        return img

# %%
root_dir_path="./img_align_celeba"

transformations = transforms.Compose([
    transforms.CenterCrop(178),
    transforms.Resize(64),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
    
])

# %%
dataset=ImageProcessor(root_dir_path,transformations)
print(f"loaded {len(dataset)} images")
# Out:
# loaded 10688 images

# %%
dataloader=DataLoader(dataset,batch_size=128,shuffle=True)

# %% [markdown]
# # Generator Network

# %%
import torch.nn as nn
class Generator(nn.Module):
    def __init__(self,z_dim=100,img_channels=3):
        super(Generator,self).__init__()

        #fully connected (dense) layers
        self.model =nn.Sequential(
            nn.Linear(z_dim,256),
            nn.ReLU(),

            nn.Linear(256,512),
            nn.ReLU(),

            nn.Linear(512,1024),
            nn.ReLU(),

            nn.Linear(1024,64 * 64 * img_channels),
            nn.Tanh(),
           
        )

    def forward(self,z):
        img=self.model(z)
        img=img.view(img.size(0),3,64,64)
        return img

# %% [markdown]
# ## discriminator network

# %%
class Discriminator(nn.Module):
    def __init__(self,img_channels=3):
        super(Discriminator,self).__init__()

        #fully connected (dense) layers
        self.model =nn.Sequential(
            nn.Flatten(),
            nn.Linear(img_channels *64*64,1024),
            nn.LeakyReLU(0.2,inplace=True),

            nn.Linear(1024,512),
            nn.LeakyReLU(),

            nn.Linear(512,256),
            nn.LeakyReLU(),

            nn.Linear(256,1),
            nn.Sigmoid(),
           
        )

    def forward(self,img):
        img=self.model(img)
        return img

# %%
import torch.optim as optim
GAN_loss=nn.BCELoss()

generator=Generator()
g_optimizer=optim.Adam(generator.parameters(),lr=0.0002,betas=(0.5,0.9999))

discriminator=Discriminator()
d_optimizer=optim.Adam(discriminator.parameters(),lr=0.0002,betas=(0.5,0.9999))

# %%
#device
import torch
if torch.backends.mps.is_available():
    device=torch.device("mps")
elif torch.cuda.is_available():
    device=torch.device("cuda")
else:
    device=torch.device("cpu")

print(f"device is {device}")
# Out:
# device is cuda

# %%
generator=generator.to(device)
discriminator=discriminator.to(device)

# %%
def train(generator, discriminator, dataloader, epochs=10):
    generator.train()
    discriminator.train()

    for epoch in range(epochs):
        for i, imgs in enumerate(dataloader):
            real_imgs = imgs.to(device)
            batch_size = real_imgs.size(0)

            # Real and fake labels
            real_labels = torch.ones(batch_size, 1).to(device)
            fake_labels = torch.zeros(batch_size, 1).to(device)

            # ----------------------
            # Train Discriminator
            # ----------------------
            d_optimizer.zero_grad()

            noise = torch.randn(batch_size, 100).to(device)
            fake_imgs = generator(noise)

            real_output = discriminator(real_imgs)
            fake_output = discriminator(fake_imgs.detach())

            real_loss = GAN_loss(real_output, real_labels)
            fake_loss = GAN_loss(fake_output, fake_labels)

            d_loss = (real_loss + fake_loss) / 2
            d_loss.backward()
            d_optimizer.step()

            # ----------------------
            # Train Generator
            # ----------------------
            g_optimizer.zero_grad()

            fake_output = discriminator(fake_imgs)
            g_loss = GAN_loss(fake_output, real_labels)

            g_loss.backward()
            g_optimizer.step()

            if i % 50 == 0:
                print(f"Epoch: {epoch}/{epochs}, Batch: {i}, G-loss: {g_loss.item():.4f}, D-loss: {d_loss.item():.4f}")

        save_generated_images(generator, epoch, device)

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\rahul shakya\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import torchvision

def save_generated_images(generator,epoch,device,num_imgs=8):
    generated_imgs=generator(torch.randn(num_imgs,100).to(device))

    grid = torchvision.utils.make_grid(generated_imgs,nrow=4,Normalize=True)
    plt.imshow(np.transport(grid,1,2,0))

    plt.title(f"epoch {epoch+1}")
    
    plt.axis("off")
    plt.show()

# %%
train(generator,discriminator,dataloader,epochs=5)
# Out:
# Epoch: 0/5, Batch: 0, G-loss: 1.5748, D-loss: 0.1861
# Epoch: 0/5, Batch: 50, G-loss: 1.0577, D-loss: 0.3167
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 train(generator,discriminator,dataloader,epochs=5)
#
# Cell In[77], line 46, in train(generator, discriminator, dataloader, epochs)
#      43     if i % 50 == 0:
#      44         print(f"Epoch: {epoch}/{epochs}, Batch: {i}, G-loss: {g_loss.item():.4f}, D-loss: {d_loss.item():.4f}")
# ---> 46 save_generated_images(generator, epoch, device)
#
# Cell In[80], line 7, in save_generated_images(generator, epoch, device, num_imgs)
#       4 def save_generated_images(generator,epoch,device,num_imgs=8):
#       5     generated_imgs=generator(torch.randn(num_imgs,100).to(device))
# ----> 7     grid = torchvision.utils.make_grid(generated_imgs,nrow=4,Normalize=True)
#       8     plt.imshow(np.transport(grid,1,2,0))
#      10     plt.title(f"epoch {epoch+1}")
#
# File ~\AppData\Local\anaconda3\envs\torchgpu\Lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# TypeError: make_grid() got an unexpected keyword argument 'Normalize'
